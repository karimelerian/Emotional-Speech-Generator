# %% [markdown]
# # Training the model on specific emotional datasets (Cloning)

# %%
# !pip install kagglehub

import kagglehub
import os
from glob import glob

# 1. Download the full dataset
data_path = kagglehub.dataset_download("uwrfkaggler/ravdess-emotional-speech-audio")

# The actual audio files are usually nested inside a specific folder within the download path
# Use glob to find all .wav files in the downloaded structure
all_files = glob(os.path.join(data_path, '**', '*.wav'), recursive=True)

# 2. Define target emotions and actor
# We will choose a single actor (e.g., Actor 12 - female)
# And a set of target emotions we want to test
TARGET_ACTOR = '12'

# We will use the 'strong' intensity (02) for maximum style transfer
# Emotion IDs: 01=Neutral, 03=Happy, 04=Sad, 05=Angry, 06=Fearful
TARGET_EMOTIONS = ['01', '03', '04', '05', '06']

print(f"Total files downloaded: {len(all_files)}")
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\Karim\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: kagglehub in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.3.13)
# Requirement already satisfied: packaging in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kagglehub) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kagglehub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kagglehub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kagglehub) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kagglehub) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->kagglehub) (0.4.6)
# Total files downloaded: 2880

# %%
# 3. Create a dictionary to store the best reference clip found for each emotion
reference_clips = {}
EMOTION_MAP = {
    '01': 'Neutral', '02': 'Calm', '03': 'Happy', '04': 'Sad',
    '05': 'Angry', '06': 'Fearful', '07': 'Disgust', '08': 'Surprised'
}

# 4. Loop through all files and apply the filters
for file_path in all_files:
    filename = os.path.basename(file_path)

    # Split the filename identifier (e.g., ['03', '01', '06', '01', '02', '01', '12'])
    parts = filename.split('.')[0].split('-')

    # Sanity check: ensure it's a speech file
    if parts[1] != '01': # Vocal channel (01 = speech)
        continue

    emotion_id = parts[2]
    intensity_id = parts[3]
    actor_id = parts[6]

    # Filter 1: Check if the file is from the target actor
    if actor_id != TARGET_ACTOR:
        continue

    # Filter 2: Check if the file is a target emotion
    if emotion_id not in TARGET_EMOTIONS:
        continue

    # Filter 3: Prioritize Strong intensity (02), except for Neutral (which only has 01)
    # We will take the first one found that meets the criteria
    if (emotion_id == '01' and intensity_id == '01') or \
       (emotion_id != '01' and intensity_id == '02'):

        emotion_name = EMOTION_MAP[emotion_id]

        # We only need one example per emotion
        if emotion_name not in reference_clips:
            reference_clips[emotion_name] = file_path

# 5. Print the selected files and create a clean directory for them
output_dir = 'ravdess_reference_clips'
os.makedirs(output_dir, exist_ok=True)
print("\n--- Selected Reference Clips ---")

for emotion, source_path in reference_clips.items():

    # Create a clean, easy-to-use filename for the Coqui model
    target_filename = f"{emotion.lower()}_ref_actor{TARGET_ACTOR}.wav"
    target_path = os.path.join(output_dir, target_filename)

    # Copy the file to the new directory
    os.system(f"cp \"{source_path}\" \"{target_path}\"")

    print(f"[{emotion}]: {os.path.basename(source_path)} copied to {target_path}")

print(f"\nPreparation complete. {len(reference_clips)} clips ready in the '{output_dir}' directory.")
# Out:
# --- Selected Reference Clips ---
# [Neutral]: 03-01-01-01-01-01-12.wav copied to ravdess_reference_clips\neutral_ref_actor12.wav
# [Happy]: 03-01-03-02-01-01-12.wav copied to ravdess_reference_clips\happy_ref_actor12.wav
# [Sad]: 03-01-04-02-01-01-12.wav copied to ravdess_reference_clips\sad_ref_actor12.wav
# [Angry]: 03-01-05-02-01-01-12.wav copied to ravdess_reference_clips\angry_ref_actor12.wav
# [Fearful]: 03-01-06-02-01-01-12.wav copied to ravdess_reference_clips\fearful_ref_actor12.wav
#
# Preparation complete. 5 clips ready in the 'ravdess_reference_clips' directory.

# %%
# !pip install TTS
import torch
import os
# !pip install coqui-tts
from TTS.api import TTS

# 1. Define Model and Target Text
MODEL_NAME = "tts_models/multilingual/multi-dataset/xtts_v2"
TARGET_TEXT = "The fox jumps over the lazy dog."
LANGUAGE = "en" # English

# 2. Get device (use CUDA if available for speed)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# 3. Initialize XTTS model
# This will download the model weights if not already present (can take a few minutes the first time)
print("Loading XTTS-v2 model...")
tts = TTS(MODEL_NAME).to(device)
print("Model loaded successfully.")

# 4. Define your reference and output directories
REF_DIR = 'ravdess_reference_clips'
OUTPUT_DIR_XTTS = 'generated_xtts_cloning'
os.makedirs(OUTPUT_DIR_XTTS, exist_ok=True)

# List of your prepared reference files:
# This list corresponds to the files you generated in the previous step's output.
reference_files = [f for f in os.listdir(REF_DIR) if f.endswith('.wav')]
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\Karim\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting TTS
#   Downloading TTS-0.22.0.tar.gz (1.7 MB)
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.7 MB 217.9 kB/s eta 0:00:08
#      -- ------------------------------------- 0.1/1.7 MB 599.1 kB/s eta 0:00:03
#      ---------- ----------------------------- 0.4/1.7 MB 1.8 MB/s eta 0:00:01
#      ------------------- -------------------- 0.8/1.7 MB 2.9 MB/s eta 0:00:01
#      --------------------------------- ------ 1.4/1.7 MB 4.2 MB/s eta 0:00:01
#      ---------------------------------------  1.6/1.7 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------------  1.6/1.7 MB 4.6 MB/s eta 0:00:01
#      ---------------------------------------- 1.7/1.7 MB 3.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.24.3 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from TTS) (2.2.3)
# Collecting cython>=0.29.30 (from TTS)
#   Downloading cython-3.2.1-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: scipy>=1.11.2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from TTS) (1.15.2)
# Requirement already satisfied: torch>=2.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from TTS) (2.6.0)
# Requirement already satisfied: torchaudio in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from TTS) (2.6.0)
# Collecting soundfile>=0.12.0 (from TTS)
#   Downloading soundfile-0.13.1-py2.py3-none-win_amd64.whl.metadata (16 kB)
# Collecting librosa>=0.10.0 (from TTS)
#   Downloading librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: scikit-learn>=1.3.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from TTS) (1.6.1)
# Collecting numba>=0.57.0 (from TTS)
#   Downloading numba-0.62.1-cp311-cp311-win_amd64.whl.metadata (2.9 kB)
# Collecting inflect>=5.6.0 (from TTS)
#   Downloading inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: tqdm>=4.64.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from TTS) (4.67.1)
# Collecting anyascii>=0.3.0 (from TTS)
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pyyaml>=6.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from TTS) (6.0.2)
# Requirement already satisfied: fsspec>=2023.6.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from TTS) (2025.3.0)
# Requirement already satisfied: aiohttp>=3.8.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from TTS) (3.11.13)
# Requirement already satisfied: packaging>=23.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from TTS) (24.2)
# Collecting flask>=2.0.1 (from TTS)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pysbd>=0.3.4 (from TTS)
#   Downloading pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting umap-learn>=0.5.1 (from TTS)
#   Downloading umap_learn-0.5.9.post2-py3-none-any.whl.metadata (25 kB)
# Collecting pandas<2.0,>=1.4 (from TTS)
#   Downloading pandas-1.5.3-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from TTS) (3.10.1)
# Collecting trainer>=0.0.32 (from TTS)
#   Downloading trainer-0.0.36-py3-none-any.whl.metadata (8.1 kB)
# Collecting coqpit>=0.0.16 (from TTS)
#   Downloading coqpit-0.0.17-py3-none-any.whl.metadata (11 kB)
# Collecting jieba (from TTS)
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#      - -------------------------------------- 0.5/19.2 MB 16.8 MB/s eta 0:00:02
#      - -------------------------------------- 0.9/19.2 MB 11.7 MB/s eta 0:00:02
#      -- ------------------------------------- 1.4/19.2 MB 11.4 MB/s eta 0:00:02
#      ---- ----------------------------------- 2.0/19.2 MB 11.7 MB/s eta 0:00:02
#      ----- ---------------------------------- 2.6/19.2 MB 13.8 MB/s eta 0:00:02
#      ------ --------------------------------- 3.1/19.2 MB 13.2 MB/s eta 0:00:02
#      ------- -------------------------------- 3.6/19.2 MB 12.8 MB/s eta 0:00:02
#      -------- ------------------------------- 4.3/19.2 MB 13.0 MB/s eta 0:00:02
#      --------- ------------------------------ 4.6/19.2 MB 12.2 MB/s eta 0:00:02
#      ---------- ----------------------------- 5.2/19.2 MB 12.2 MB/s eta 0:00:02
#      ----------- ---------------------------- 5.6/19.2 MB 12.0 MB/s eta 0:00:02
#      ------------ --------------------------- 6.1/19.2 MB 12.2 MB/s eta 0:00:02
#      ------------- -------------------------- 6.7/19.2 MB 12.3 MB/s eta 0:00:02
#      --------------- ------------------------ 7.2/19.2 MB 12.5 MB/s eta 0:00:01
#      ---------------- ----------------------- 7.8/19.2 MB 12.4 MB/s eta 0:00:01
#      ----------------- ---------------------- 8.4/19.2 MB 12.5 MB/s eta 0:00:01
#      ------------------ --------------------- 9.0/19.2 MB 12.5 MB/s eta 0:00:01
#      ------------------- -------------------- 9.5/19.2 MB 12.7 MB/s eta 0:00:01
#      -------------------- ------------------- 9.8/19.2 MB 12.1 MB/s eta 0:00:01
#      -------------------- ------------------ 10.3/19.2 MB 12.1 MB/s eta 0:00:01
#      --------------------- ----------------- 10.8/19.2 MB 12.1 MB/s eta 0:00:01
#      ---------------------- ---------------- 11.3/19.2 MB 12.1 MB/s eta 0:00:01
#      ------------------------ -------------- 11.9/19.2 MB 12.1 MB/s eta 0:00:01
#      ------------------------- ------------- 12.3/19.2 MB 12.1 MB/s eta 0:00:01
#      -------------------------- ------------ 12.8/19.2 MB 11.9 MB/s eta 0:00:01
#      -------------------------- ------------ 13.2/19.2 MB 11.5 MB/s eta 0:00:01
#      --------------------------- ----------- 13.7/19.2 MB 11.7 MB/s eta 0:00:01
#      ---------------------------- ---------- 14.3/19.2 MB 11.7 MB/s eta 0:00:01
#      ------------------------------ -------- 14.8/19.2 MB 11.9 MB/s eta 0:00:01
#      ------------------------------- ------- 15.3/19.2 MB 11.9 MB/s eta 0:00:01
#      -------------------------------- ------ 15.8/19.2 MB 11.9 MB/s eta 0:00:01
#      --------------------------------- ----- 16.5/19.2 MB 11.9 MB/s eta 0:00:01
#      ---------------------------------- ---- 17.0/19.2 MB 11.9 MB/s eta 0:00:01
#      ----------------------------------- --- 17.5/19.2 MB 11.9 MB/s eta 0:00:01
#      ------------------------------------ -- 18.0/19.2 MB 11.7 MB/s eta 0:00:01
#      ------------------------------------- - 18.5/19.2 MB 11.5 MB/s eta 0:00:01
#      --------------------------------------  19.1/19.2 MB 11.5 MB/s eta 0:00:01
#      --------------------------------------  19.2/19.2 MB 11.5 MB/s eta 0:00:01
#      --------------------------------------  19.2/19.2 MB 11.5 MB/s eta 0:00:01
#      --------------------------------------- 19.2/19.2 MB 10.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pypinyin (from TTS)
#   Downloading pypinyin-0.55.0-py2.py3-none-any.whl.metadata (12 kB)
# Collecting hangul_romanize (from TTS)
#   Downloading hangul_romanize-0.1.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting gruut==2.2.3 (from gruut[de,es,fr]==2.2.3->TTS)
#   Downloading gruut-2.2.3.tar.gz (73 kB)
#      ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#      ---------------------------------------- 73.5/73.5 kB 2.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting jamo (from TTS)
#   Downloading jamo-0.4.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting nltk (from TTS)
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting g2pkk>=0.1.1 (from TTS)
#   Downloading g2pkk-0.1.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting bangla (from TTS)
#   Downloading bangla-0.0.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting bnnumerizer (from TTS)
#   Downloading bnnumerizer-0.0.2.tar.gz (4.7 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting bnunicodenormalizer (from TTS)
#   Downloading bnunicodenormalizer-0.1.7-py3-none-any.whl.metadata (22 kB)
# Collecting einops>=0.6.0 (from TTS)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting transformers>=4.33.0 (from TTS)
#   Downloading transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/44.0 kB ? eta -:--:--
#      ---------------------------------------- 44.0/44.0 kB 2.3 MB/s eta 0:00:00
# Collecting encodec>=0.1.1 (from TTS)
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#      ------ --------------------------------- 0.6/3.7 MB 20.5 MB/s eta 0:00:01
#      ------------ --------------------------- 1.2/3.7 MB 15.1 MB/s eta 0:00:01
#      -------------------- ------------------- 1.9/3.7 MB 15.1 MB/s eta 0:00:01
#      -------------------------- ------------- 2.5/3.7 MB 14.3 MB/s eta 0:00:01
#      ----------------------------------- ---- 3.3/3.7 MB 15.0 MB/s eta 0:00:01
#      ---------------------------------------  3.7/3.7 MB 14.9 MB/s eta 0:00:01
#      ---------------------------------------- 3.7/3.7 MB 12.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting unidecode>=1.3.2 (from TTS)
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Collecting num2words (from TTS)
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Collecting spacy>=3 (from spacy[ja]>=3->TTS)
#   Downloading spacy-3.8.11-cp311-cp311-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (2.17.0)
# Collecting dateparser~=1.1.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS)
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl.metadata (27 kB)
# Collecting gruut-ipa<1.0,>=0.12.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS)
#   Downloading gruut-ipa-0.13.0.tar.gz (101 kB)
#      ---------------------------------------- 0.0/101.6 kB ? eta -:--:--
#      -------------------------------------- 101.6/101.6 kB 6.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting gruut_lang_en~=2.0.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS)
#   Downloading gruut_lang_en-2.0.1.tar.gz (15.3 MB)
#      ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#      - -------------------------------------- 0.6/15.3 MB 12.9 MB/s eta 0:00:02
#      --- ------------------------------------ 1.3/15.3 MB 13.6 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.8/15.3 MB 13.0 MB/s eta 0:00:02
#      ------ --------------------------------- 2.5/15.3 MB 14.6 MB/s eta 0:00:01
#      -------- ------------------------------- 3.1/15.3 MB 13.4 MB/s eta 0:00:01
#      --------- ------------------------------ 3.7/15.3 MB 13.8 MB/s eta 0:00:01
#      ----------- ---------------------------- 4.2/15.3 MB 13.4 MB/s eta 0:00:01
#      ------------ --------------------------- 4.8/15.3 MB 13.8 MB/s eta 0:00:01
#      ------------- -------------------------- 5.2/15.3 MB 13.4 MB/s eta 0:00:01
#      --------------- ------------------------ 5.8/15.3 MB 13.2 MB/s eta 0:00:01
#      ---------------- ----------------------- 6.3/15.3 MB 13.4 MB/s eta 0:00:01
#      ----------------- ---------------------- 6.8/15.3 MB 13.2 MB/s eta 0:00:01
#      ------------------- -------------------- 7.4/15.3 MB 13.1 MB/s eta 0:00:01
#      -------------------- ------------------- 8.0/15.3 MB 13.5 MB/s eta 0:00:01
#      ---------------------- ----------------- 8.6/15.3 MB 13.7 MB/s eta 0:00:01
#      ------------------------ --------------- 9.2/15.3 MB 13.6 MB/s eta 0:00:01
#      ------------------------- -------------- 9.7/15.3 MB 13.5 MB/s eta 0:00:01
#      -------------------------- ------------ 10.3/15.3 MB 13.4 MB/s eta 0:00:01
#      --------------------------- ----------- 10.8/15.3 MB 13.6 MB/s eta 0:00:01
#      ---------------------------- ---------- 11.3/15.3 MB 13.4 MB/s eta 0:00:01
#      ----------------------------- --------- 11.6/15.3 MB 13.1 MB/s eta 0:00:01
#      ------------------------------ -------- 12.0/15.3 MB 12.8 MB/s eta 0:00:01
#      -------------------------------- ------ 12.6/15.3 MB 12.8 MB/s eta 0:00:01
#      --------------------------------- ----- 13.1/15.3 MB 12.8 MB/s eta 0:00:01
#      ---------------------------------- ---- 13.7/15.3 MB 12.6 MB/s eta 0:00:01
#      ------------------------------------ -- 14.2/15.3 MB 12.8 MB/s eta 0:00:01
#      ------------------------------------- - 14.7/15.3 MB 12.8 MB/s eta 0:00:01
#      --------------------------------------  15.2/15.3 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------  15.3/15.3 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------  15.3/15.3 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------- 15.3/15.3 MB 11.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting jsonlines~=1.2.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS)
#   Downloading jsonlines-1.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting networkx<3.0.0,>=2.5.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS)
#   Downloading networkx-2.8.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting numpy>=1.24.3 (from TTS)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# Collecting python-crfsuite~=0.9.7 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS)
#   Downloading python_crfsuite-0.9.11-cp311-cp311-win_amd64.whl.metadata (4.4 kB)
# Collecting gruut_lang_de~=2.0.0 (from gruut[de,es,fr]==2.2.3->TTS)
#   Downloading gruut_lang_de-2.0.1.tar.gz (18.1 MB)
#      ---------------------------------------- 0.0/18.1 MB ? eta -:--:--
#      - -------------------------------------- 0.6/18.1 MB 18.2 MB/s eta 0:00:01
#      -- ------------------------------------- 1.1/18.1 MB 14.2 MB/s eta 0:00:02
#      --- ------------------------------------ 1.6/18.1 MB 13.0 MB/s eta 0:00:02
#      ---- ----------------------------------- 2.3/18.1 MB 14.4 MB/s eta 0:00:02
#      ------ --------------------------------- 2.7/18.1 MB 13.4 MB/s eta 0:00:02
#      ------ --------------------------------- 3.2/18.1 MB 13.5 MB/s eta 0:00:02
#      -------- ------------------------------- 3.7/18.1 MB 13.0 MB/s eta 0:00:02
#      --------- ------------------------------ 4.2/18.1 MB 12.8 MB/s eta 0:00:02
#      ---------- ----------------------------- 4.8/18.1 MB 12.7 MB/s eta 0:00:02
#      ----------- ---------------------------- 5.3/18.1 MB 12.9 MB/s eta 0:00:01
#      ------------ --------------------------- 5.7/18.1 MB 12.5 MB/s eta 0:00:01
#      -------------- ------------------------- 6.4/18.1 MB 12.7 MB/s eta 0:00:01
#      --------------- ------------------------ 6.9/18.1 MB 13.0 MB/s eta 0:00:01
#      ---------------- ----------------------- 7.5/18.1 MB 13.0 MB/s eta 0:00:01
#      ----------------- ---------------------- 8.0/18.1 MB 12.8 MB/s eta 0:00:01
#      ------------------ --------------------- 8.6/18.1 MB 13.0 MB/s eta 0:00:01
#      ------------------- -------------------- 9.0/18.1 MB 12.8 MB/s eta 0:00:01
#      --------------------- ------------------ 9.6/18.1 MB 13.0 MB/s eta 0:00:01
#      --------------------- ----------------- 10.1/18.1 MB 12.9 MB/s eta 0:00:01
#      ----------------------- --------------- 10.8/18.1 MB 12.8 MB/s eta 0:00:01
#      ------------------------ -------------- 11.3/18.1 MB 12.8 MB/s eta 0:00:01
#      ------------------------- ------------- 11.9/18.1 MB 12.8 MB/s eta 0:00:01
#      -------------------------- ------------ 12.4/18.1 MB 12.6 MB/s eta 0:00:01
#      --------------------------- ----------- 13.0/18.1 MB 12.6 MB/s eta 0:00:01
#      ----------------------------- --------- 13.5/18.1 MB 13.1 MB/s eta 0:00:01
#      ------------------------------ -------- 14.0/18.1 MB 12.8 MB/s eta 0:00:01
#      ------------------------------- ------- 14.6/18.1 MB 13.1 MB/s eta 0:00:01
#      -------------------------------- ------ 15.1/18.1 MB 13.1 MB/s eta 0:00:01
#      --------------------------------- ----- 15.7/18.1 MB 13.1 MB/s eta 0:00:01
#      ----------------------------------- --- 16.3/18.1 MB 12.8 MB/s eta 0:00:01
#      ------------------------------------ -- 16.9/18.1 MB 12.8 MB/s eta 0:00:01
#      ------------------------------------- - 17.5/18.1 MB 13.1 MB/s eta 0:00:01
#      --------------------------------------  18.0/18.1 MB 12.8 MB/s eta 0:00:01
#      --------------------------------------  18.1/18.1 MB 12.8 MB/s eta 0:00:01
#      --------------------------------------  18.1/18.1 MB 12.8 MB/s eta 0:00:01
#      --------------------------------------  18.1/18.1 MB 12.8 MB/s eta 0:00:01
#      --------------------------------------  18.1/18.1 MB 12.8 MB/s eta 0:00:01
#      --------------------------------------  18.1/18.1 MB 12.8 MB/s eta 0:00:01
#      --------------------------------------- 18.1/18.1 MB 10.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting gruut_lang_es~=2.0.0 (from gruut[de,es,fr]==2.2.3->TTS)
#   Downloading gruut_lang_es-2.0.1.tar.gz (31.4 MB)
#      ---------------------------------------- 0.0/31.4 MB ? eta -:--:--
#       --------------------------------------- 0.6/31.4 MB 19.5 MB/s eta 0:00:02
#      - -------------------------------------- 1.1/31.4 MB 14.4 MB/s eta 0:00:03
#      -- ------------------------------------- 1.7/31.4 MB 13.4 MB/s eta 0:00:03
#      -- ------------------------------------- 2.2/31.4 MB 14.2 MB/s eta 0:00:03
#      --- ------------------------------------ 2.8/31.4 MB 12.7 MB/s eta 0:00:03
#      ---- ----------------------------------- 3.5/31.4 MB 13.8 MB/s eta 0:00:03
#      ----- ---------------------------------- 4.0/31.4 MB 13.5 MB/s eta 0:00:03
#      ----- ---------------------------------- 4.6/31.4 MB 13.3 MB/s eta 0:00:03
#      ------ --------------------------------- 5.1/31.4 MB 13.6 MB/s eta 0:00:02
#      ------ --------------------------------- 5.4/31.4 MB 12.8 MB/s eta 0:00:03
#      ------- -------------------------------- 5.9/31.4 MB 12.6 MB/s eta 0:00:03
#      -------- ------------------------------- 6.5/31.4 MB 12.9 MB/s eta 0:00:02
#      --------- ------------------------------ 7.1/31.4 MB 13.0 MB/s eta 0:00:02
#      --------- ------------------------------ 7.7/31.4 MB 13.2 MB/s eta 0:00:02
#      ---------- ----------------------------- 8.2/31.4 MB 13.1 MB/s eta 0:00:02
#      ----------- ---------------------------- 8.7/31.4 MB 12.9 MB/s eta 0:00:02
#      ----------- ---------------------------- 9.2/31.4 MB 13.0 MB/s eta 0:00:02
#      ------------ --------------------------- 9.7/31.4 MB 12.9 MB/s eta 0:00:02
#      ------------ -------------------------- 10.2/31.4 MB 12.8 MB/s eta 0:00:02
#      ------------- ------------------------- 10.8/31.4 MB 12.4 MB/s eta 0:00:02
#      ------------- ------------------------- 11.3/31.4 MB 12.6 MB/s eta 0:00:02
#      -------------- ------------------------ 11.8/31.4 MB 12.6 MB/s eta 0:00:02
#      --------------- ----------------------- 12.3/31.4 MB 12.4 MB/s eta 0:00:02
#      ---------------- ---------------------- 13.0/31.4 MB 12.6 MB/s eta 0:00:02
#      ---------------- ---------------------- 13.6/31.4 MB 12.6 MB/s eta 0:00:02
#      ----------------- --------------------- 14.2/31.4 MB 12.6 MB/s eta 0:00:02
#      ------------------ -------------------- 14.7/31.4 MB 12.6 MB/s eta 0:00:02
#      ------------------ -------------------- 15.2/31.4 MB 12.6 MB/s eta 0:00:02
#      ------------------- ------------------- 15.7/31.4 MB 12.8 MB/s eta 0:00:02
#      -------------------- ------------------ 16.4/31.4 MB 12.8 MB/s eta 0:00:02
#      -------------------- ------------------ 16.9/31.4 MB 12.8 MB/s eta 0:00:02
#      --------------------- ----------------- 17.4/31.4 MB 12.8 MB/s eta 0:00:02
#      ---------------------- ---------------- 17.9/31.4 MB 12.8 MB/s eta 0:00:02
#      ----------------------- --------------- 18.6/31.4 MB 13.1 MB/s eta 0:00:01
#      ----------------------- --------------- 19.1/31.4 MB 12.8 MB/s eta 0:00:01
#      ------------------------ -------------- 19.5/31.4 MB 13.1 MB/s eta 0:00:01
#      ------------------------- ------------- 20.1/31.4 MB 12.8 MB/s eta 0:00:01
#      ------------------------- ------------- 20.7/31.4 MB 13.1 MB/s eta 0:00:01
#      -------------------------- ------------ 21.4/31.4 MB 12.8 MB/s eta 0:00:01
#      --------------------------- ----------- 22.0/31.4 MB 13.1 MB/s eta 0:00:01
#      --------------------------- ----------- 22.5/31.4 MB 12.9 MB/s eta 0:00:01
#      ---------------------------- ---------- 23.1/31.4 MB 13.1 MB/s eta 0:00:01
#      ----------------------------- --------- 23.7/31.4 MB 13.4 MB/s eta 0:00:01
#      ------------------------------ -------- 24.3/31.4 MB 13.4 MB/s eta 0:00:01
#      ------------------------------ -------- 24.8/31.4 MB 13.1 MB/s eta 0:00:01
#      ------------------------------- ------- 25.3/31.4 MB 13.4 MB/s eta 0:00:01
#      -------------------------------- ------ 25.9/31.4 MB 13.4 MB/s eta 0:00:01
#      -------------------------------- ------ 26.4/31.4 MB 13.4 MB/s eta 0:00:01
#      --------------------------------- ----- 26.9/31.4 MB 13.4 MB/s eta 0:00:01
#      ---------------------------------- ---- 27.5/31.4 MB 13.4 MB/s eta 0:00:01
#      ---------------------------------- ---- 28.0/31.4 MB 13.4 MB/s eta 0:00:01
#      ----------------------------------- --- 28.5/31.4 MB 13.1 MB/s eta 0:00:01
#      ------------------------------------ -- 29.2/31.4 MB 13.4 MB/s eta 0:00:01
#      ------------------------------------- - 29.8/31.4 MB 13.4 MB/s eta 0:00:01
#      ------------------------------------- - 30.5/31.4 MB 13.4 MB/s eta 0:00:01
#      --------------------------------------  31.0/31.4 MB 13.4 MB/s eta 0:00:01
#      --------------------------------------  31.4/31.4 MB 13.4 MB/s eta 0:00:01
#      --------------------------------------  31.4/31.4 MB 13.4 MB/s eta 0:00:01
#      --------------------------------------  31.4/31.4 MB 13.4 MB/s eta 0:00:01
#      --------------------------------------  31.4/31.4 MB 13.4 MB/s eta 0:00:01
#      --------------------------------------- 31.4/31.4 MB 11.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting gruut_lang_fr~=2.0.0 (from gruut[de,es,fr]==2.2.3->TTS)
#   Downloading gruut_lang_fr-2.0.2.tar.gz (10.9 MB)
#      ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#      -- ------------------------------------- 0.6/10.9 MB 11.8 MB/s eta 0:00:01
#      ---- ----------------------------------- 1.1/10.9 MB 13.9 MB/s eta 0:00:01
#      ----- ---------------------------------- 1.6/10.9 MB 12.8 MB/s eta 0:00:01
#      -------- ------------------------------- 2.2/10.9 MB 12.7 MB/s eta 0:00:01
#      ---------- ----------------------------- 2.8/10.9 MB 12.6 MB/s eta 0:00:01
#      ------------ --------------------------- 3.3/10.9 MB 13.4 MB/s eta 0:00:01
#      -------------- ------------------------- 3.9/10.9 MB 13.0 MB/s eta 0:00:01
#      --------------- ------------------------ 4.4/10.9 MB 12.6 MB/s eta 0:00:01
#      ------------------ --------------------- 5.0/10.9 MB 13.2 MB/s eta 0:00:01
#      -------------------- ------------------- 5.6/10.9 MB 12.9 MB/s eta 0:00:01
#      ---------------------- ----------------- 6.2/10.9 MB 12.8 MB/s eta 0:00:01
#      ------------------------ --------------- 6.7/10.9 MB 12.9 MB/s eta 0:00:01
#      -------------------------- ------------- 7.2/10.9 MB 12.7 MB/s eta 0:00:01
#      --------------------------- ------------ 7.5/10.9 MB 12.6 MB/s eta 0:00:01
#      ---------------------------- ----------- 7.9/10.9 MB 12.3 MB/s eta 0:00:01
#      ------------------------------ --------- 8.4/10.9 MB 12.2 MB/s eta 0:00:01
#      -------------------------------- ------- 8.9/10.9 MB 12.4 MB/s eta 0:00:01
#      ----------------------------------- ---- 9.6/10.9 MB 12.3 MB/s eta 0:00:01
#      ----------------------------------- --- 10.1/10.9 MB 12.4 MB/s eta 0:00:01
#      --------------------------------------  10.8/10.9 MB 12.4 MB/s eta 0:00:01
#      --------------------------------------  10.9/10.9 MB 12.1 MB/s eta 0:00:01
#      --------------------------------------- 10.9/10.9 MB 11.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp>=3.8.1->TTS) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp>=3.8.1->TTS) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp>=3.8.1->TTS) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp>=3.8.1->TTS) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp>=3.8.1->TTS) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp>=3.8.1->TTS) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp>=3.8.1->TTS) (1.18.3)
# Collecting blinker>=1.9.0 (from flask>=2.0.1->TTS)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from flask>=2.0.1->TTS)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting itsdangerous>=2.2.0 (from flask>=2.0.1->TTS)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask>=2.0.1->TTS) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from flask>=2.0.1->TTS) (3.0.2)
# Collecting werkzeug>=3.1.0 (from flask>=2.0.1->TTS)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting more_itertools>=8.5.0 (from inflect>=5.6.0->TTS)
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting typeguard>=4.0.1 (from inflect>=5.6.0->TTS)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting audioread>=2.1.9 (from librosa>=0.10.0->TTS)
#   Downloading audioread-3.1.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: joblib>=1.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa>=0.10.0->TTS) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa>=0.10.0->TTS) (5.2.1)
# Collecting pooch>=1.1 (from librosa>=0.10.0->TTS)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa>=0.10.0->TTS)
#   Downloading soxr-1.0.0-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa>=0.10.0->TTS) (4.12.2)
# Collecting lazy_loader>=0.1 (from librosa>=0.10.0->TTS)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa>=0.10.0->TTS)
#   Downloading msgpack-1.1.2-cp311-cp311-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.7.0->TTS) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.7.0->TTS) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.7.0->TTS) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.7.0->TTS) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.7.0->TTS) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.7.0->TTS) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.7.0->TTS) (2.9.0.post0)
# Collecting docopt>=0.6.2 (from num2words->TTS)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba>=0.57.0->TTS)
#   Downloading llvmlite-0.45.1-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<2.0,>=1.4->TTS) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.3.0->TTS) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from soundfile>=0.12.0->TTS) (1.17.1)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy>=3->spacy[ja]>=3->TTS)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy>=3->spacy[ja]>=3->TTS)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy>=3->spacy[ja]>=3->TTS)
#   Downloading murmurhash-1.0.15-cp311-cp311-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy>=3->spacy[ja]>=3->TTS)
#   Downloading cymem-2.0.13-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy>=3->spacy[ja]>=3->TTS)
#   Downloading preshed-3.0.12-cp311-cp311-win_amd64.whl.metadata (2.6 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy>=3->spacy[ja]>=3->TTS)
#   Downloading thinc-8.3.10-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy>=3->spacy[ja]>=3->TTS)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy>=3->spacy[ja]>=3->TTS)
#   Downloading srsly-2.5.2-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy>=3->spacy[ja]>=3->TTS)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.4.2 (from spacy>=3->spacy[ja]>=3->TTS)
#   Downloading weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer-slim<1.0.0,>=0.3.0 (from spacy>=3->spacy[ja]>=3->TTS)
#   Downloading typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.31.0)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy>=3->spacy[ja]>=3->TTS)
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
#      ---------------------------------------- 0.0/89.9 kB ? eta -:--:--
#      ---------------------------------------- 89.9/89.9 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from spacy>=3->spacy[ja]>=3->TTS) (65.5.0)
# Collecting sudachipy!=0.6.1,>=0.5.2 (from spacy[ja]>=3->TTS)
#   Downloading SudachiPy-0.6.10-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting sudachidict_core>=20211220 (from spacy[ja]>=3->TTS)
#   Downloading sudachidict_core-20251022-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: filelock in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.1->TTS) (3.17.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=2.1->TTS) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy==1.13.1->torch>=2.1->TTS) (1.3.0)
# Requirement already satisfied: colorama in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.64.1->TTS) (0.4.6)
# Requirement already satisfied: psutil in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from trainer>=0.0.32->TTS) (7.0.0)
# Collecting tensorboard (from trainer>=0.0.32->TTS)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers>=4.33.0->TTS)
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Collecting regex!=2019.12.17 (from transformers>=4.33.0->TTS)
#   Downloading regex-2025.11.3-cp311-cp311-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 41.5/41.5 kB ? eta 0:00:00
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers>=4.33.0->TTS)
#   Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers>=4.33.0->TTS)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.1->TTS)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: pycparser in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=1.0->soundfile>=0.12.0->TTS) (2.22)
# Collecting tzlocal (from dateparser~=1.1.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: six in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonlines~=1.2.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pooch>=1.1->librosa>=0.10.0->TTS) (4.3.6)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS)
#   Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting typing_extensions>=4.1.1 (from librosa>=0.10.0->TTS)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (2023.7.22)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy>=3->spacy[ja]>=3->TTS)
#   Downloading blis-1.3.3-cp311-cp311-win_amd64.whl.metadata (7.7 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy>=3->spacy[ja]>=3->TTS)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.4.2->spacy>=3->spacy[ja]>=3->TTS)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.4.2->spacy>=3->spacy[ja]>=3->TTS)
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting absl-py>=0.4 (from tensorboard->trainer>=0.0.32->TTS)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->trainer>=0.0.32->TTS)
#   Downloading grpcio-1.76.0-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Collecting markdown>=2.6.8 (from tensorboard->trainer>=0.0.32->TTS)
#   Downloading markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard->trainer>=0.0.32->TTS)
#   Downloading protobuf-6.33.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->trainer>=0.0.32->TTS)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy>=3->spacy[ja]>=3->TTS)
#   Downloading wrapt-2.0.1-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: tzdata in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tzlocal->dateparser~=1.1.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (2025.1)
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.1 kB ? eta -:--:--
#    --------------------------------------- 345.1/345.1 kB 10.5 MB/s eta 0:00:00
# Downloading coqpit-0.0.17-py3-none-any.whl (13 kB)
# Downloading cython-3.2.1-cp311-cp311-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 15.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.8/2.8 MB 12.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.4/2.8 MB 12.3 MB/s eta 0:00:01
#    --------------------------- ------------ 1.9/2.8 MB 12.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.8 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------  2.8/2.8 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 11.0 MB/s eta 0:00:00
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.4 kB ? eta -:--:--
#    ---------------------------------------- 64.4/64.4 kB 3.4 MB/s eta 0:00:00
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.3 kB ? eta -:--:--
#    ---------------------------------------- 103.3/103.3 kB 6.2 MB/s eta 0:00:00
# Downloading g2pkk-0.1.2-py3-none-any.whl (25 kB)
# Downloading inflect-7.5.0-py3-none-any.whl (35 kB)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
#    ---------------------------------------- 0.0/260.7 kB ? eta -:--:--
#    --------------------------------------- 260.7/260.7 kB 15.7 MB/s eta 0:00:00
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.5 kB ? eta -:--:--
#    ---------------------------------------- 163.5/163.5 kB 9.6 MB/s eta 0:00:00
# Downloading numba-0.62.1-cp311-cp311-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --------- ------------------------------ 0.7/2.7 MB 21.5 MB/s eta 0:00:01
#    -------------- ------------------------- 1.0/2.7 MB 13.0 MB/s eta 0:00:01
#    -------------------- ------------------- 1.4/2.7 MB 11.4 MB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.7 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 13.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 11.6 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    - -------------------------------------- 0.8/15.8 MB 24.0 MB/s eta 0:00:01
#    --- ------------------------------------ 1.5/15.8 MB 19.4 MB/s eta 0:00:01
#    ----- ---------------------------------- 2.0/15.8 MB 18.5 MB/s eta 0:00:01
#    ------ --------------------------------- 2.6/15.8 MB 18.4 MB/s eta 0:00:01
#    -------- ------------------------------- 3.3/15.8 MB 17.6 MB/s eta 0:00:01
#    --------- ------------------------------ 3.8/15.8 MB 16.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 4.6/15.8 MB 16.4 MB/s eta 0:00:01
#    ------------- -------------------------- 5.2/15.8 MB 16.5 MB/s eta 0:00:01
#    -------------- ------------------------- 5.8/15.8 MB 16.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.5/15.8 MB 16.0 MB/s eta 0:00:01
#    ------------------ --------------------- 7.3/15.8 MB 16.6 MB/s eta 0:00:01
#    ------------------- -------------------- 7.9/15.8 MB 16.8 MB/s eta 0:00:01
#    --------------------- ------------------ 8.6/15.8 MB 16.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.2/15.8 MB 16.3 MB/s eta 0:00:01
#    ------------------------ --------------- 9.8/15.8 MB 16.0 MB/s eta 0:00:01
#    -------------------------- ------------- 10.5/15.8 MB 16.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.1/15.8 MB 15.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.8/15.8 MB 15.6 MB/s eta 0:00:01
# ...
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy==1.13.1->torch<2.9,>=2.1->coqui-tts) (1.3.0)
# Requirement already satisfied: colorama in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.64.1->coqui-tts) (0.4.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<4.56,>=4.52.1->coqui-tts) (0.36.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<4.56,>=4.52.1->coqui-tts) (2025.11.3)
# Requirement already satisfied: requests in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<4.56,>=4.52.1->coqui-tts) (2.31.0)
# Collecting tokenizers<0.22,>=0.21 (from transformers<4.56,>=4.52.1->coqui-tts)
#   Downloading tokenizers-0.21.4-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<4.56,>=4.52.1->coqui-tts) (0.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (1.18.3)
# Requirement already satisfied: pycparser in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=1.0->soundfile>=0.12.0->coqui-tts) (2.22)
# Requirement already satisfied: pytz in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts) (2025.1)
# Requirement already satisfied: tzlocal in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts) (5.3.1)
# Requirement already satisfied: six in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonlines~=1.2.0->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pooch>=1.1->librosa>=0.11.0->coqui-tts) (4.3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->transformers<4.56,>=4.52.1->coqui-tts) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->transformers<4.56,>=4.52.1->coqui-tts) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->transformers<4.56,>=4.52.1->coqui-tts) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->transformers<4.56,>=4.52.1->coqui-tts) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.1.0->librosa>=0.11.0->coqui-tts) (3.5.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (6.33.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (65.5.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch<2.9,>=2.1->coqui-tts) (3.0.2)
# Requirement already satisfied: tzdata in c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tzlocal->dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts) (2025.1)
# Downloading coqui_tts-0.27.2-py3-none-any.whl (858 kB)
#    ---------------------------------------- 0.0/858.4 kB ? eta -:--:--
#    --------- ------------------------------ 204.8/858.4 kB 6.1 MB/s eta 0:00:01
#    -------------- ------------------------- 317.4/858.4 kB 4.9 MB/s eta 0:00:01
#    ------------------------ --------------- 522.2/858.4 kB 4.1 MB/s eta 0:00:01
#    -------------------------------- ------- 696.3/858.4 kB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  849.9/858.4 kB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 858.4/858.4 kB 4.2 MB/s eta 0:00:00
# Downloading coqpit_config-0.2.1-py3-none-any.whl (15 kB)
# Downloading coqui_tts_trainer-0.3.1-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.2 kB ? eta -:--:--
#    ---------------------------------------- 57.2/57.2 kB 2.9 MB/s eta 0:00:00
# Downloading monotonic_alignment_search-0.2.1-cp311-cp311-win_amd64.whl (228 kB)
#    ---------------------------------------- 0.0/228.9 kB ? eta -:--:--
#    ---------------------------------------  225.3/228.9 kB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 228.9/228.9 kB 3.5 MB/s eta 0:00:00
# Downloading transformers-4.55.4-py3-none-any.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.3 MB 5.9 MB/s eta 0:00:02
#    - -------------------------------------- 0.4/11.3 MB 5.0 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/11.3 MB 5.9 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/11.3 MB 5.4 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/11.3 MB 5.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.4/11.3 MB 5.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.3 MB 5.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.0/11.3 MB 6.0 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/11.3 MB 6.0 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.3 MB 6.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.0/11.3 MB 6.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.2/11.3 MB 6.4 MB/s eta 0:00:02
#    ------------ --------------------------- 3.6/11.3 MB 6.8 MB/s eta 0:00:02
#    ------------- -------------------------- 3.9/11.3 MB 6.8 MB/s eta 0:00:02
#    --------------- ------------------------ 4.3/11.3 MB 7.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.5/11.3 MB 7.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.0/11.3 MB 7.2 MB/s eta 0:00:01
#    ------------------- -------------------- 5.4/11.3 MB 7.4 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.3 MB 7.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/11.3 MB 7.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.3 MB 7.5 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.3 MB 7.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.6/11.3 MB 7.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.2/11.3 MB 8.1 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.3 MB 8.2 MB/s eta 0:00:01
#    -------------------------------- ------- 9.2/11.3 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.3 MB 8.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.3 MB 8.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.3 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 9.0 MB/s eta 0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.5 MB 9.8 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.5 MB 10.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.4/2.5 MB 11.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.9/2.5 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.3/2.5 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 10.0 MB/s eta 0:00:00
# Building wheels for collected packages: gruut
#   Building wheel for gruut (pyproject.toml): started
#   Building wheel for gruut (pyproject.toml): finished with status 'done'
#   Created wheel for gruut: filename=gruut-2.4.0-py3-none-any.whl size=86915 sha256=cf3ebf3b03324c964a7f74ca2c6127e4a698871d426137cebbfd5a27e8cd1885
#   Stored in directory: c:\users\karim\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\7f\ff\c1\291e91d9b767694fb7f30f6cd16a5b89d6d67afacd796ad842
# Successfully built gruut
# Installing collected packages: monotonic-alignment-search, coqpit-config, tokenizers, gruut, coqui-tts-trainer, transformers, coqui-tts
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Uninstalling tokenizers-0.22.1:
#       Successfully uninstalled tokenizers-0.22.1
#   Attempting uninstall: gruut
#     Found existing installation: gruut 2.2.3
#     Uninstalling gruut-2.2.3:
#       Successfully uninstalled gruut-2.2.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.1
#     Uninstalling transformers-4.57.1:
#       Successfully uninstalled transformers-4.57.1
# Successfully installed coqpit-config-0.2.1 coqui-tts-0.27.2 coqui-tts-trainer-0.3.1 gruut-2.4.0 monotonic-alignment-search-0.2.1 tokenizers-0.21.4 transformers-4.55.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tts 0.22.0 requires gruut[de,es,fr]==2.2.3, but you have gruut 2.4.0 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\Karim\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 5
#       3 import os
#       4 get_ipython().system('pip install coqui-tts')
# ----> 5 from TTS.api import TTS
#       7 # 1. Define Model and Target Text
#       8 MODEL_NAME = "tts_models/multilingual/multi-dataset/xtts_v2"
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\TTS\__init__.py:14
#       7 if "coqpit" in importlib.metadata.packages_distributions().get("coqpit", []):
#       8     msg = (
#       9         "coqui-tts switched to a forked version of Coqpit, but you still have the original "
#      10         "package installed. Run the following to avoid conflicts:\n"
#      11         "  pip uninstall coqpit\n"
#      12         "  pip install coqpit-config"
#      13     )
# ---> 14     raise ImportError(msg)
#      17 if is_pytorch_at_least_2_4():
#      18     import _codecs
#
# ImportError: coqui-tts switched to a forked version of Coqpit, but you still have the original package installed. Run the following to avoid conflicts:
#   pip uninstall coqpit
#   pip install coqpit-config

# %%
# 5. Define target text, directories, and list of references
TARGET_TEXT = "Karim is amazing, I love Karim."
REF_DIR = 'ravdess_reference_clips'
OUTPUT_DIR_XTTS = 'generated_xtts_cloning'
# Note: You already created the output directory and defined reference_files earlier,
# but we'll redefine the files list here in case the kernel was reset.

import os
# Assumes files are in the ravdess_reference_clips directory
reference_files = [f for f in os.listdir(REF_DIR) if f.endswith('.wav')]
os.makedirs(OUTPUT_DIR_XTTS, exist_ok=True)

# 6. Loop through each reference clip and generate the emotional output
print("\n--- Starting XTTS Generation (Voice Cloning) ---")
for ref_file in reference_files:
    # Example ref_file: sad_ref_actor12.wav
    emotion_name = ref_file.split('_')[0].capitalize()
    ref_path = os.path.join(REF_DIR, ref_file)

    output_filename = f"{emotion_name}_XTTS_Clone.wav"
    output_path = os.path.join(OUTPUT_DIR_XTTS, output_filename)

    print(f"Generating [{emotion_name}] using {ref_file}...")

    try:
        # XTTS-v2 Generation command: uses the ref_path as the speaker_wav
        tts.tts_to_file(
            text=TARGET_TEXT,
            speaker_wav=ref_path,
            language="en", # Must match the language used for the model and text
            file_path=output_path,
        )
        print(f"SUCCESS: {output_filename}")

    except Exception as e:
        print(f"ERROR generating {emotion_name}: {e}")

print(f"\nXTTS generation complete. {len(reference_files)} samples saved in '{OUTPUT_DIR_XTTS}'.")
# Out:
# --- Starting XTTS Generation (Voice Cloning) ---
#
# XTTS generation complete. 0 samples saved in 'generated_xtts_cloning'.

# %% [markdown]
# # Suno Bark Generation (Text Prompting)
